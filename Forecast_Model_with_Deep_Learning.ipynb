# %% [markdown]
# <a href="https://colab.research.google.com/github/mboya2020/Mtoto-News-Childline-Kenya-call-volume-forecast-model.ipynb/blob/main/Forecast_Model_with_Deep_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 3.Loading the Data

# %% [markdown]
# ### 3.1 Loading the libraries

# %% [markdown]
# Connecting to Google drive and Importing all the necessary Libraries | Modules.

# %%
# connecting collab to google drive

from google.colab import drive
drive.mount('/drive')
# Out:
# Mounted at /drive

# %%
# loading libraries

from pandas import DataFrame, read_csv,read_excel
import pandas as pd
import numpy as np
import os, shutil


# visualization libraries
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### 3.2 Loading the data

# %% [markdown]
# Load the data using os.listdir method

# %%
# print the contents of the mtoto news childline kenya folder 

print(os.listdir('/drive/Shareddrives/Eagles/mtoto_news_childline_kenya'))
# Out:
# ['WeatherNairobi2016.xls', 'NairobiSchoolDates2016.csv', 'Sample_Submission.csv', 'KenyaPublicHolidays2016.csv', 'train.csv']

# %%
 #store the file paths as variables

weather_file = ('/drive/Shareddrives/Eagles/mtoto_news_childline_kenya/WeatherNairobi2016.xls')
dates_file = ('/drive/Shareddrives/Eagles/mtoto_news_childline_kenya/NairobiSchoolDates2016.csv')
submission_file = ('/drive/Shareddrives/Eagles/mtoto_news_childline_kenya/Sample_Submission.csv')
holidays_file = ('/drive/Shareddrives/Eagles/mtoto_news_childline_kenya/KenyaPublicHolidays2016.csv')
train_file = ('/drive/Shareddrives/Eagles/mtoto_news_childline_kenya/train.csv')

# %% [markdown]
# View contents of the files

# %%
#print the data in the train file 

train = pd.read_csv(train_file)
train.head(3)
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (12,13,14,18) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#               calldate cc_status             maincat     subcat1  \
# 0  2016-01-01 07:26:47    Closed  non-interventional  Blank call
# 1  2016-01-01 07:32:30    Closed  non-interventional  Blank call
# 2  2016-01-01 07:44:31    Closed  non-interventional  Blank call
#
#    casepriority referal caller_gender caller_age caller_county child_age  \
# 0  Non Critical     NaN           NaN        NaN           NaN       NaN
# 1  Non Critical     NaN           NaN        NaN           NaN       NaN
# 2  Non Critical     NaN           NaN        NaN           NaN       NaN
#
#   child_gender child_county parent_age parent_gender parent_county  \
# 0          NaN          NaN        NaN           NaN           NaN
# ...

# %%
#print the data in the dates file 

train = pd.read_csv(dates_file)
train.head(3)
# Out:
#    Term     Opening     Closing  Unnamed: 3  Unnamed: 4  \
# 0     1  2016-01-04  2016-04-08         NaN         NaN
# 1     2  2016-05-02  2016-08-05         NaN         NaN
# 2     3  2016-09-05  2016-11-18         NaN         NaN
#
#                                           Unnamed: 5
# 0                                    *year/month/day
# 1  https://www.standardmedia.co.ke/article/200018...
# 2                                                NaN

# %%
#print the data in the submission file 

train = pd.read_csv(submission_file)
train.head(3)
# Out:
#    time_index  calls
# 0  2016071300   28.0
# 1  2016071301   98.0
# 2  2016071302    NaN

# %%
#print the data in the holidays file 

train = pd.read_csv(holidays_file)
train.head()
# Out:
#   Public holidays Kenya 2017  \
# 0                        NaN
# 1                       Date
# 2                 2016/01/01
# 3                 2016/03/25
# 4                 2016/03/28
#
#   https://www.officeholidays.com/countries/kenya/2016.php Unnamed: 2
# 0                                                NaN             NaN
# 1                                            Holiday             NaN
# 2                                      New Years Day             NaN
# 3                                        Good Friday             NaN
# 4                                      Easter Monday             NaN

# %%
pip install xlrd>=1.2.0

# %%
#print the data in the weather file 

#weather = pd.read_excel(weather_file)

# Read the values of the file in the dataframe
#weather_data = pd.DataFrame(weather,columns= ['Local time in Nairobi (airport)', 'T',	'Po',	'P',	'Pa',	'U',	'DD',	'Ff',	'ff10',	'ff3',	'N',	'WW',	'W1',	'W2',	'Tn',	'Tx',	'Cl',	'Nh',	'H',	'Cm',	'Ch',	'VV',	'Td',	'RRR',	'tR',	'E',	'Tg',	'E',	'sss'])
# Print the content
#print("The content of the file is:\n", weather_data)

# %%
pip install xlrd>=1.2.0
